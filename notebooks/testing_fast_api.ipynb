# %%
import requests
from fastapi import FastAPI, HTTPException
from pydantic import BaseModel
from typing import List, Dict, Any
from datetime import datetime

# %%
import mlflow
import numpy as np
import joblib
import re
import pandas as pd
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
from mlflow.tracking import MlflowClient
import matplotlib.dates as mdates

def preprocess_comment(comment: str) -> str:
    try:
        comment = comment.lower()
        comment = comment.strip()
        comment = re.sub(r"\n", " ", comment)
        comment = re.sub(r"[^A-Za-z0-9\s!?.,]", "", comment)

        stop_words = set(stopwords.words("english")) - {
            "not", "but", "however", "no", "yet"
        }

        comment = " ".join(
            [word for word in comment.split() if word not in stop_words]
        )

        lemmatizer = WordNetLemmatizer()
        comment = " ".join(
            [lemmatizer.lemmatize(word) for word in comment.split()]
        )

        return comment

    except Exception as e:
        print(f"Error in preprocessing comment: {e}")
        return comment

# -------------------------
# MLflow loader
# -------------------------
def load_model_and_vectorizer(model_name, model_version, vectorizer_path):
    mlflow.set_tracking_uri(
        "https://dagshub.com/Pranay5519/yt-comment-sentiment-analysis-2.mlflow"
    )

    client = MlflowClient()

    model_uri = f"models:/{model_name}/{model_version}"
    model = mlflow.lightgbm.load_model(model_uri)

    vectorizer = joblib.load(vectorizer_path)

    return model, vectorizer

model, vectorizer = load_model_and_vectorizer(
    "ligbm_model_v1", "1", r"D:\yt-comment-sentiment-analysis2\tfidf_vectorizer.pkl"
)
# Out:
# ---------------------------------------------------------------------------
# RestException                             Traceback (most recent call last)
# Cell In[2], line 54
#      50     vectorizer = joblib.load(vectorizer_path)
#      52     return model, vectorizer
# ---> 54 model, vectorizer = load_model_and_vectorizer(
#      55     "ligbm_model_v1", "1", r"D:\yt-comment-sentiment-analysis2\tfidf_vectorizer.pkl"
#      56 )
#
# Cell In[2], line 48, in load_model_and_vectorizer(model_name, model_version, vectorizer_path)
#      45 client = MlflowClient()
#      47 model_uri = f"models:/{model_name}/{model_version}"
# ---> 48 model = mlflow.lightgbm.load_model(model_uri)
#      50 vectorizer = joblib.load(vectorizer_path)
#      52 return model, vectorizer
#
# File d:\yt-comment-sentiment-analysis2\myenv\Lib\site-packages\mlflow\lightgbm\__init__.py:541, in load_model(model_uri, dst_path)
#     488 def load_model(model_uri, dst_path=None):
#     489     """
#     490     Load a LightGBM model from a local file or a run.
#     491
#    (...)
#     539         [0 0 0 0 0]
#     540     """
# --> 541     local_model_path = _download_artifact_from_uri(artifact_uri=model_uri, output_path=dst_path)
#     542     flavor_conf = _get_flavor_configuration(local_model_path, FLAVOR_NAME)
#     543     _add_code_from_conf_to_system_path(local_model_path, flavor_conf)
#
# File d:\yt-comment-sentiment-analysis2\myenv\Lib\site-packages\mlflow\tracking\artifact_utils.py:117, in _download_artifact_from_uri(artifact_uri, output_path, lineage_header_info, tracking_uri, registry_uri)
#     107 """
#     108 Args:
#     109     artifact_uri: The *absolute* URI of the artifact to download.
#    (...)
#     114     registry_uri: The registry URI to be used when downloading artifacts.
#     115 """
#     116 root_uri, artifact_path = _get_root_uri_and_artifact_path(artifact_uri)
# --> 117 repo = get_artifact_repository(
#     118     artifact_uri=root_uri, tracking_uri=tracking_uri, registry_uri=registry_uri
#     119 )
#     121 try:
#     122     if isinstance(repo, ModelsArtifactRepository):
#
# File d:\yt-comment-sentiment-analysis2\myenv\Lib\site-packages\mlflow\store\artifact\artifact_repository_registry.py:147, in get_artifact_repository(artifact_uri, tracking_uri, registry_uri)
#     128 def get_artifact_repository(
#     129     artifact_uri: str, tracking_uri: str | None = None, registry_uri: str | None = None
#     130 ) -> ArtifactRepository:
#     131     """
#     132     Get an artifact repository from the registry based on the scheme of artifact_uri
#     133
#    (...)
#     145         requirements.
#     146     """
# --> 147     return _artifact_repository_registry.get_artifact_repository(
#     148         artifact_uri, tracking_uri, registry_uri
#     149     )
#
# File d:\yt-comment-sentiment-analysis2\myenv\Lib\site-packages\mlflow\store\artifact\artifact_repository_registry.py:83, in ArtifactRepositoryRegistry.get_artifact_repository(self, artifact_uri, tracking_uri, registry_uri)
#      78 if repository is None:
#      79     raise MlflowException(
#      80         f"Could not find a registered artifact repository for: {artifact_uri}. "
#      81         f"Currently registered schemes are: {list(self._registry.keys())}"
#      82     )
# ---> 83 return repository(artifact_uri, tracking_uri=tracking_uri, registry_uri=registry_uri)
#
# File d:\yt-comment-sentiment-analysis2\myenv\Lib\site-packages\mlflow\store\artifact\models_artifact_repo.py:83, in ModelsArtifactRepository.__init__(self, artifact_uri, tracking_uri, registry_uri)
#      77     self.model_version = self.repo.model_version
#      78 else:
#      79     (
#      80         self.model_name,
#      81         self.model_version,
#      82         underlying_uri,
# ---> 83     ) = ModelsArtifactRepository._get_model_uri_infos(artifact_uri)
#      84     self.repo = get_artifact_repository(
#      85         underlying_uri, tracking_uri=tracking_uri, registry_uri=registry_uri
#      86     )
#
# File d:\yt-comment-sentiment-analysis2\myenv\Lib\site-packages\mlflow\store\artifact\models_artifact_repo.py:144, in ModelsArtifactRepository._get_model_uri_infos(uri)
#     142 else:
#     143     name, version = name_and_version_or_id
# --> 144     download_uri = client.get_model_version_download_uri(name, version)
#     146 return (
#     147     name,
#     148     version,
#     149     add_databricks_profile_info_to_artifact_uri(download_uri, databricks_profile_uri),
#     150 )
#
# File d:\yt-comment-sentiment-analysis2\myenv\Lib\site-packages\mlflow\tracking\client.py:5011, in MlflowClient.get_model_version_download_uri(self, name, version)
#    4966 def get_model_version_download_uri(self, name: str, version: str) -> str:
#    4967     """
#    4968     Get the download location in Model Registry for this model version.
#    4969
#    (...)
#    5009         Download URI: runs:/027d7bbe81924c5a82b3e4ce979fcab7/sklearn-model
#    5010     """
# -> 5011     self._raise_if_prompt(name)
#    5012     return self._get_registry_client().get_model_version_download_uri(name, version)
#
# File d:\yt-comment-sentiment-analysis2\myenv\Lib\site-packages\mlflow\tracking\client.py:5619, in MlflowClient._raise_if_prompt(self, name)
#    5615 def _raise_if_prompt(self, name: str) -> None:
#    5616     """
#    5617     Validate if the given name is registered as a Prompt rather than a Registered Model.
#    5618     """
# -> 5619     rm = self.get_registered_model(name)
#    5620     if has_prompt_tag(rm._tags):
#    5621         raise _model_not_found(name)
#
# File d:\yt-comment-sentiment-analysis2\myenv\Lib\site-packages\mlflow\tracking\client.py:4186, in MlflowClient.get_registered_model(self, name)
#    4145 def get_registered_model(self, name: str) -> RegisteredModel:
#    4146     """Get a registered model.
#    4147
#    4148     Args:
#    (...)
#    4184         description: This sentiment analysis model classifies the tone-happy, sad, angry.
#    4185     """
# -> 4186     rm = self._get_registry_client().get_registered_model(name)
#    4188     # Prompt should not be returned as a registered model
#    4189     if has_prompt_tag(rm._tags):
#
# File d:\yt-comment-sentiment-analysis2\myenv\Lib\site-packages\mlflow\tracking\_model_registry\client.py:181, in ModelRegistryClient.get_registered_model(self, name)
#     173 def get_registered_model(self, name):
#     174     """
#     175     Args:
#     176         name: Name of the registered model to get.
#    (...)
#     179         A single :py:class:`mlflow.entities.model_registry.RegisteredModel` object.
#     180     """
# --> 181     return self.store.get_registered_model(name)
#
# File d:\yt-comment-sentiment-analysis2\myenv\Lib\site-packages\mlflow\store\model_registry\rest_store.py:205, in RestStore.get_registered_model(self, name)
#     195 """
#     196 Get registered model instance by name.
#     197
#    (...)
#     202     A single :py:class:`mlflow.entities.model_registry.RegisteredModel` object.
#     203 """
#     204 req_body = message_to_json(GetRegisteredModel(name=name))
# --> 205 response_proto = self._call_endpoint(GetRegisteredModel, req_body)
#     206 return RegisteredModel.from_proto(response_proto.registered_model)
#
# File d:\yt-comment-sentiment-analysis2\myenv\Lib\site-packages\mlflow\store\model_registry\base_rest_store.py:42, in BaseRestStore._call_endpoint(self, api, json_body, call_all_endpoints, extra_headers)
#      40 else:
#      41     endpoint, method = self._get_endpoint_from_method(api)
# ---> 42     return call_endpoint(
#      43         self.get_host_creds(), endpoint, method, json_body, response_proto, extra_headers
#      44     )
#
# File d:\yt-comment-sentiment-analysis2\myenv\Lib\site-packages\mlflow\utils\rest_utils.py:596, in call_endpoint(host_creds, endpoint, method, json_body, response_proto, extra_headers, retry_timeout_seconds)
#     593     call_kwargs["json"] = json_body
#     594     response = http_request(**call_kwargs)
# --> 596 response = verify_rest_response(response, endpoint)
#     597 response_to_parse = response.text
#     598 try:
#
# File d:\yt-comment-sentiment-analysis2\myenv\Lib\site-packages\mlflow\utils\rest_utils.py:315, in verify_rest_response(response, endpoint)
#     313 if response.status_code != 200:
#     314     if _can_parse_as_json_object(response.text):
# --> 315         raise RestException(json.loads(response.text))
#     316     else:
#     317         base_msg = (
#     318             f"API request to endpoint {endpoint} "
#     319             f"failed with error code {response.status_code} != 200"
#     320         )
#
# RestException: RESOURCE_DOES_NOT_EXIST: Response: {'error_code': 'RESOURCE_DOES_NOT_EXIST'}

# %%
model , vectorizer
# Out:
# (LGBMClassifier(class_weight='balanced', is_unbalance=True, learning_rate=0.09,
#                 max_depth=20, metric='multi_logloss', n_estimators=367,
#                 num_class=3, objective='multiclass', reg_alpha=0.1,
#                 reg_lambda=0.1),
#  TfidfVectorizer(max_features=10000, ngram_range=(1, 3)))

# %%
class Comment(BaseModel):
    text: str
    timestamp: datetime
    authorId: str

class PredictRequest(BaseModel):
    comments: List[Comment]
    
class PredictWithTimestampRequest(BaseModel):
    comments : List[Comment]

# %%
def predict(comments: PredictRequest):
    
    if not comments:
        raise HTTPException(status_code=400, detail="No comments provided")

    try:
        # Preprocess comments
        preprocessed_comments = [
            preprocess_comment(c.text) for c in comments.comments
        ]
        print("preprocessing Done")
        # Vectorize comments (sparse matrix)
        transformed_comments = vectorizer.transform(preprocessed_comments)
        print("Transformation Done")

        # Get expected schema columns from MLflow model
        #input_schema = model.metadata.get_input_schema()
        #expected_columns = input_schema.input_names()

        # Convert sparse matrix to DataFrame with vectorizer features
        feature_names = vectorizer.get_feature_names_out()
        df = pd.DataFrame(
                    transformed_comments.toarray(),
                    columns=feature_names
                )
        print("Data Frame Generated")
# 🔥 correct alignment for MLflow
        #df = df.reindex(columns=expected_columns, fill_value=0.0)
        ## Reorder columns exactly as model expects
        #df = df[expected_columns]

        # Make predictions
        predictions = model.predict(df).tolist()
        # Convert predictions to strings
        predictions = [str(pred) for pred in predictions]
        print("predictions : ", predictions)

    except Exception as e:
        raise HTTPException(
            status_code=500,
            detail=f"Prediction failed: {str(e)}"
        )

    # Return response (same structure as Flask)
    response = [
        {"comment": comment, "sentiment": sentiment}
        for comment, sentiment in zip(comments.comments, predictions)
    ]

    return response

# %%
comments = {
  "comments": [
    {
      "text": "Come get a real Land Cruiser in South Africa, here you can actually do shit like you can in america, as long as you arent endangering anyone you can do whatever you want and theres no filming restrictions either. Id argue we're even more free than the US in these regards. And we also have the new Hilux's as well the land cruisers",
      "timestamp": "2026-01-30T14:37:22Z",
      "authorId": "UCWUoKxg8-WVQZzERTnW8IBg"
    },
    {
      "text": "we were promised a Bugatti durability test and instead got a campout in a pos Toyota in sand.",
      "timestamp": "2026-01-30T14:37:20Z",
      "authorId": "UC6lZYcaMIhNAbbZ6xkn6FDg"
    },
    {
      "text": "Buy property in Alaska!!!",
      "timestamp": "2026-01-30T14:37:18Z",
      "authorId": "UCoZE-D5YtR8qH-fLhNGiwqg"
    }
  ]
}

# %%
for item in comments["comments"]:
    print(item["text"])
# Out:
# Come get a real Land Cruiser in South Africa, here you can actually do shit like you can in america, as long as you arent endangering anyone you can do whatever you want and theres no filming restrictions either. Id argue we're even more free than the US in these regards. And we also have the new Hilux's as well the land cruisers
# we were promised a Bugatti durability test and instead got a campout in a pos Toyota in sand.
# Buy property in Alaska!!!

# %%
from nltk.corpus import stopwords
import re
from nltk.stem import WordNetLemmatizer
import nltk
nltk.download('stopwords')
def preprocess_comment(comment: str) -> str:
    try:
        comment = comment.lower()
        comment = comment.strip()
        comment = re.sub(r"\n", " ", comment)
        comment = re.sub(r"[^A-Za-z0-9\s!?.,]", "", comment)

        stop_words = set(stopwords.words("english")) - {
            "not", "but", "however", "no", "yet"
        }

        comment = " ".join(
            [word for word in comment.split() if word not in stop_words]
        )

        lemmatizer = WordNetLemmatizer()
        comment = " ".join(
            [lemmatizer.lemmatize(word) for word in comment.split()]
        )

        return comment

    except Exception as e:
        print(e)
        return comment
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\prana\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
preprocessed_comments = [
        preprocess_comment(c["text"]) for c in comments["comments"]
    ]

preprocessed_comments
# Out:
# ['come get real land cruiser south africa, actually shit like america, long arent endangering anyone whatever want there no filming restriction either. id argue even free u regards. also new hiluxs well land cruiser',
#  'promised bugatti durability test instead got campout po toyota sand.',
#  'buy property alaska!!!']

# %%
tokens = 0
for x in preprocessed_comments:
    tokens+=len(x)
INPUT_TOKENS.inc(tokens)
# Out:
# 303

# %%
tokens = sum(len(x) for x in preprocessed_comments)
tokens
# Out:
# 303

# %%
predictions = ["0" , "1" , "-1"  ]

for pred in predictions:
    if pred == "1":
        POSITIVE_COUNTER.inc()
    elif pred =="0":
        NEUTRAL_COUNTER.inc()
    else:
        NEGATIVE_COUNTER.inc()
