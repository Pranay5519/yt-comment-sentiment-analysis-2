# %% [markdown]
# ## Load model and vectorizer

# %%
import os
import mlflow
import dagshub
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
dagshub_token = os.getenv("DAGSHUB_PAT")
if not dagshub_token:
    raise EnvironmentError("DAGSHUB_PAT environment variable is not set")
os.environ["MLFLOW_TRACKING_USERNAME"] = dagshub_token
os.environ["MLFLOW_TRACKING_PASSWORD"] = dagshub_token

dagshub_url = "https://dagshub.com"
repo_owner = "Pranay5519"
repo_name = "yt-comment-sentiment-analysis"

# Set up MLflow tracking URI
mlflow.set_tracking_uri(f'{dagshub_url}/{repo_owner}/{repo_name}.mlflow')

# %%
model_uri = f"models:/yt_chrome_plugin_model/staging"
model = mlflow.pyfunc.load_model(model_uri)
# Out:
# 2026/01/18 10:50:00 WARNING mlflow.utils.requirements_utils: Detected one or more mismatches between the model's dependencies and the current Python environment:
#  - mlflow (current: 3.8.1, required: mlflow==2.16.2)
#  - cloudpickle (current: 3.1.2, required: cloudpickle==3.1.1)
#  - matplotlib (current: 3.10.8, required: matplotlib==3.10.5)
#  - numpy (current: 2.4.1, required: numpy==2.3.2)
#  - pandas (current: 2.3.3, required: pandas==2.3.1)
#  - pyarrow (current: 22.0.0, required: pyarrow==17.0.0)
#  - scikit-learn (current: 1.8.0, required: scikit-learn==1.7.1)
#  - scipy (current: 1.17.0, required: scipy==1.16.1)
# To fix the mismatches, call `mlflow.pyfunc.get_model_dependencies(model_uri)` to fetch the model's environment and install dependencies using the resulting environment file.
# d:\yt-comment-sentiment-analysis2\myenv\Lib\site-packages\sklearn\base.py:463: InconsistentVersionWarning: Trying to unpickle estimator LabelEncoder from version 1.7.1 when using version 1.8.0. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(

# %%
model
# Out:
# mlflow.pyfunc.loaded_model:
#   artifact_path: lgbm_model
#   flavor: mlflow.sklearn
#   run_id: 8f046e5f6ad640859a094ad43af9bd8b

# %%
import joblib
tfidf_vectorizer = joblib.load(r"D:\yt-comment-sentiment-analysis2\tfidf_vectorizer.pkl")
# Out:
# d:\yt-comment-sentiment-analysis2\myenv\Lib\site-packages\sklearn\base.py:463: InconsistentVersionWarning: Trying to unpickle estimator TfidfTransformer from version 1.7.1 when using version 1.8.0. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# d:\yt-comment-sentiment-analysis2\myenv\Lib\site-packages\sklearn\base.py:463: InconsistentVersionWarning: Trying to unpickle estimator TfidfVectorizer from version 1.7.1 when using version 1.8.0. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(

# %% [markdown]
# ## Load Comments Function

# %%
import os
import joblib
import mlflow
import dagshub
from mlflow.tracking import MlflowClient
from dotenv import load_dotenv
load_dotenv()
def load_model_and_vectorizer(model_name, model_version, vectorizer_path):
    dagshub_token = os.getenv("DAGSHUB_PAT")
    if not dagshub_token:
        raise EnvironmentError("DAGSHUB_PAT environment variable is not set")

    os.environ["MLFLOW_TRACKING_USERNAME"] = dagshub_token
    os.environ["MLFLOW_TRACKING_PASSWORD"] = dagshub_token

    dagshub_url = "https://dagshub.com"
    repo_owner = "Pranay5519"
    repo_name = "yt-comment-sentiment-analysis"

    # Set up MLflow tracking URI
    mlflow.set_tracking_uri(f'{dagshub_url}/{repo_owner}/{repo_name}.mlflow')
    client = MlflowClient()
    model_uri = f"models:/{model_name}/{model_version}"
    model = mlflow.pyfunc.load_model(model_uri)
    vectorizer = joblib.load(vectorizer_path)  # Load the vectorizer
    return model, vectorizer
# Initialize the model and vectorizer
vec_path = r"D:\yt-comment-sentiment-analysis2\tfidf_vectorizer.pkl"
model, vectorizer = load_model_and_vectorizer("yt_chrome_plugin_model", "2", vec_path)  # Update paths and versions as needed
# Out:
# Downloading artifacts: 100%|██████████| 7/7 [00:04<00:00,  1.44it/s]
# 2026/01/18 12:20:27 WARNING mlflow.utils.requirements_utils: Detected one or more mismatches between the model's dependencies and the current Python environment:
#  - mlflow (current: 3.8.1, required: mlflow==2.15.0)
#  - cffi (current: 2.0.0, required: cffi==1.16.0)
#  - cloudpickle (current: 3.1.2, required: cloudpickle==3.0.0)
#  - lightgbm (current: 4.6.0, required: lightgbm==4.5.0)
#  - matplotlib (current: 3.10.8, required: matplotlib==3.9.1)
#  - numpy (current: 2.4.1, required: numpy==1.26.4)
#  - pandas (current: 2.3.3, required: pandas==2.2.2)
#  - psutil (current: 7.2.1, required: psutil==6.0.0)
#  - pyarrow (current: 22.0.0, required: pyarrow==15.0.2)
#  - scikit-learn (current: 1.8.0, required: scikit-learn==1.5.1)
#  - scipy (current: 1.17.0, required: scipy==1.14.0)
# To fix the mismatches, call `mlflow.pyfunc.get_model_dependencies(model_uri)` to fetch the model's environment and install dependencies using the resulting environment file.
# 2026/01/18 12:20:27 WARNING mlflow.pyfunc: The version of Python that the model was saved in, `Python 3.10.18`, differs from the version of Python that is currently running, `Python 3.11.9`, and may be incompatible
# d:\yt-comment-sentiment-analysis2\myenv\Lib\site-packages\sklearn\base.py:463: InconsistentVersionWarning: Trying to unpickle estimator LabelEncoder from version 1.5.1 when using version 1.8.0. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# d:\yt-comment-sentiment-analysis2\myenv\Lib\site-packages\sklearn\base.py:463: InconsistentVersionWarning: Trying to unpickle estimator TfidfTransformer from version 1.7.1 when using version 1.8.0. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# d:\yt-comment-sentiment-analysis2\myenv\Lib\site-packages\sklearn\base.py:463: InconsistentVersionWarning: Trying to unpickle estimator TfidfVectorizer from version 1.7.1 when using version 1.8.0. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(

# %%
import requests

def fetch_comments(video_id: str, api_key: str, max_comments: int = 500):
    comments = []
    page_token = ""

    try:
        while len(comments) < max_comments:
            url = "https://www.googleapis.com/youtube/v3/commentThreads"
            params = {
                "part": "snippet",
                "videoId": video_id,
                "maxResults": 100,
                "pageToken": page_token,
                "key": api_key
            }

            response = requests.get(url, params=params)
            response.raise_for_status()
            data = response.json()

            if "items" in data:
                for item in data["items"]:
                    snippet = item["snippet"]["topLevelComment"]["snippet"]

                    comment_text = snippet.get("textOriginal")
                    timestamp = snippet.get("publishedAt")
                    author_id = (
                        snippet.get("authorChannelId", {}).get("value", "Unknown")
                    )

                    comments.append({
                        "text": comment_text,
                        "timestamp": timestamp,
                        "authorId": author_id
                    })

                    if len(comments) >= max_comments:
                        break

            page_token = data.get("nextPageToken")
            if not page_token:
                break

    except requests.exceptions.RequestException as e:
        print("Error fetching comments:", e)

    return comments

# %%
import re
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
def preprocess_comment(comment):
    """Apply preprocessing transformations to a comment."""
    try:
        # Convert to lowercase
        comment = comment.lower()

        # Remove trailing and leading whitespaces
        comment = comment.strip()

        # Remove newline characters
        comment = re.sub(r'\n', ' ', comment)

        # Remove non-alphanumeric characters, except punctuation
        comment = re.sub(r'[^A-Za-z0-9\s!?.,]', '', comment)

        # Remove stopwords but retain important ones for sentiment analysis
        stop_words = set(stopwords.words('english')) - {'not', 'but', 'however', 'no', 'yet'}
        comment = ' '.join([word for word in comment.split() if word not in stop_words])

        # Lemmatize the words
        lemmatizer = WordNetLemmatizer()
        comment = ' '.join([lemmatizer.lemmatize(word) for word in comment.split()])

        return comment
    except Exception as e:
        print(f"Error in preprocessing comment: {e}")
        return comment

# %%
API_KEY = os.getenv("API_KEY")
VIDEO_ID = "RmwbNdyrilk"

comments = fetch_comments(VIDEO_ID, API_KEY)
print(len(comments))
print(comments[0])
# Out:
# 96
# {'text': 'Thank you for watching. Please click the subscribe tab and then the "bell" icon to subscribe to our channel here on YouTube and get notified when new content is posted... And thank you for your interest in science!   -- Andrew', 'timestamp': '2026-01-15T13:23:20Z', 'authorId': 'UC2D2CMWXMOVWx7giW1n3LIg'}

# %%
import pandas as pd

def predict_sentiment(comments):
    if not comments:
        return {"error": "No comments provided"}

    try:
        # 1. Preprocess comments
        preprocessed_comments = [
            preprocess_comment(comment["text"]) for comment in comments
        ]

        # 2. Vectorize comments (sparse matrix)
        transformed_comments = vectorizer.transform(preprocessed_comments)

        # 3. Get expected schema columns from MLflow model
        input_schema = model.metadata.get_input_schema()
        expected_columns = input_schema.input_names()

        # 4. Convert sparse matrix to DataFrame
        feature_names = vectorizer.get_feature_names_out()
        df = pd.DataFrame(
            transformed_comments.toarray(),
            columns=feature_names
        )

        # 5. Add missing expected columns AT ONCE (fixes fragmentation)
        missing_cols = set(expected_columns) - set(df.columns)
        if missing_cols:
            missing_df = pd.DataFrame(
                0.0,
                index=df.index,
                columns=list(missing_cols)
            )
            df = pd.concat([df, missing_df], axis=1)

        # 6. Reorder columns exactly as model expects
        df = df[expected_columns]

        # 7. Predict
        predictions = model.predict(df).astype(str).tolist()

    except Exception as e:
        return {"error": str(e)}

    # 8. Build response
    return [
        {"comment": comment, "sentiment": sentiment}
        for comment, sentiment in zip(comments, predictions)
    ]
import pandas as pd

def predict_with_timestamps(comments_data):
    if not comments_data:
        return {"error": "No comments provided"}

    try:
        # 1. Extract text and timestamps
        comments = [item["text"] for item in comments_data]
        timestamps = [item["timestamp"] for item in comments_data]

        # 2. Preprocess comments
        preprocessed_comments = [
            preprocess_comment(comment) for comment in comments
        ]

        # 3. Vectorize comments
        transformed_comments = vectorizer.transform(preprocessed_comments)

        # 4. Get expected schema columns from MLflow model
        input_schema = model.metadata.get_input_schema()
        expected_columns = input_schema.input_names()

        # 5. Convert sparse matrix to DataFrame
        feature_names = vectorizer.get_feature_names_out()
        df = pd.DataFrame(
            transformed_comments.toarray(),
            columns=feature_names
        )

        # 6. Add missing columns in ONE operation (fixes warning)
        missing_cols = set(expected_columns) - set(df.columns)
        if missing_cols:
            missing_df = pd.DataFrame(
                0.0,
                index=df.index,
                columns=list(missing_cols)
            )
            df = pd.concat([df, missing_df], axis=1)

        # 7. Reorder columns exactly as model expects
        df = df[expected_columns]

        # 8. Predict
        predictions = model.predict(df).astype(str).tolist()

    except Exception as e:
        return {"error": f"Prediction failed: {str(e)}"}

    # 9. Build response with timestamps
    return [
        {
            "comment": comment,
            "sentiment": sentiment,
            "timestamp": timestamp
        }
        for comment, sentiment, timestamp in zip(
            comments, predictions, timestamps
        )
    ]

# %%
predict_sentiment(comments=comments)
# Out:
# [{'comment': {'text': 'Thank you for watching. Please click the subscribe tab and then the "bell" icon to subscribe to our channel here on YouTube and get notified when new content is posted... And thank you for your interest in science!   -- Andrew',
#    'timestamp': '2026-01-15T13:23:20Z',
#    'authorId': 'UC2D2CMWXMOVWx7giW1n3LIg'},
#   'sentiment': '1'},
#  {'comment': {'text': 'To make a better world✌🏼',
#    'timestamp': '2026-01-18T05:46:32Z',
#    'authorId': 'UCD9dMGvb-NXnTl-qLge4vTA'},
#   'sentiment': '1'},
#  {'comment': {'text': 'Can we get a collaboration with cam hanes and goggins with other ultra triathlon/marathon athletes and other high intense athletes and have Dr. Andrew Huberman, Dr. Wendy Suzuki, and Robert Sapolsky dissect the correlation between exercise, will power, and building new neural processes in the brain and how they interact with each other?',
#    'timestamp': '2026-01-18T04:34:25Z',
#    'authorId': 'UC217yaW7WVxsDdaXeQPDIhg'},
#   'sentiment': '1'},
#  {'comment': {'text': '31:50 - What in the world!?  Sounds insane.',
#    'timestamp': '2026-01-17T15:36:44Z',
#    'authorId': 'UCE2x1ggUSGHdHSk3qGok2iA'},
#   'sentiment': '-1'},
#  {'comment': {'text': 'I would love an episode on self-esteem and or perfectionism! :)',
#    'timestamp': '2026-01-17T14:20:39Z',
#    'authorId': 'UC_hGlA89Dr7wM8KJtpWl9IA'},
#   'sentiment': '1'},
#  {'comment': {'text': "I know this is a cut down version of a longer conversation and there's a heavy focus on physical activity here, but what about diet? There probably has been episodes which talk more specifically about food, but no mention on it from Dr Wendy as an important part of boosting attention and memory?",
#    'timestamp': '2026-01-17T07:29:55Z',
#    'authorId': 'UCuxvI-kXja6fQq9m1-lJYTg'},
#   'sentiment': '1'},
#  {'comment': {'text': "sorry to hear Wendy's home was broken into,  but I just have to say how lucky were are they didn’t actually steal the best thing in her home. Which is Wendy herself !! ❤",
#    'timestamp': '2026-01-17T05:40:13Z',
#    'authorId': 'UCMuCdyshmp5F_DhLcliAduA'},
#   'sentiment': '1'},
#  {'comment': {'text': 'Really found this interesting not boring at all 😊😊',
#    'timestamp': '2026-01-16T21:53:49Z',
#    'authorId': 'UCF-EH-C6SeLxsPBCVmc7IwA'},
#   'sentiment': '1'},
#  {'comment': {'text': 'Thanks wendy you are amazing',
#    'timestamp': '2026-01-16T20:28:57Z',
#    'authorId': 'UCdf28XJe7iPZuV7l4Lx16uA'},
#   'sentiment': '1'},
#  {'comment': {'text': 'Please invite Dr Joe dizpenza',
#    'timestamp': '2026-01-16T18:47:53Z',
#    'authorId': 'UCHtc1IbzGtJ3_vD-iS9mvPQ'},
#   'sentiment': '0'},
#  {'comment': {'text': 'So your brains performance is up after exercise? Or is it up during exercise and after that goes slowly back to baseline?',
#    'timestamp': '2026-01-16T17:48:20Z',
#    'authorId': 'UCtQLVr4KCG4sjg3JYuNXJ6g'},
#   'sentiment': '-1'},
#  {'comment': {'text': 'I love Huberman’s work, and maybe that’s why this feels so disappointing. Lately the podcast seems to be coasting—reposting old “essential” episodes( I love them but i have already seen them) or bringing on guests who don’t match the depth he used to deliver solo.\nThe magic was never the production or the guests—it was Huberman alone, clearly driven, diving deep into topics he cared about —digging deep, connecting dots, and pulling out real gems. That sense of exploration and intellectual hunger feels missing now. is he not an explorer anymore rummaging through papers ?\n\nI still respect the work—but I miss the version of this podcast that felt alive.',
#    'timestamp': '2026-01-16T15:49:24Z',
#    'authorId': 'UC-e3smI_gTVZJZ2Sj7PJRaQ'},
#   'sentiment': '1'},
#  {'comment': {'text': "Is it exercise sleep and diet? I haven't watched yet",
#    'timestamp': '2026-01-16T15:23:03Z',
#    'authorId': 'UC3nMUNDUDr1ILqjgfeEPK7A'},
#   'sentiment': '0'},
#  {'comment': {'text': 'Make video on  student proper strategy for long answer to write in exam ..... how to study revise recall please discuss everything',
#    'timestamp': '2026-01-16T15:01:07Z',
#    'authorId': 'UCdFwo1q1mRrxZT41D2jRzjQ'},
#   'sentiment': '-1'},
#  {'comment': {'text': 'This reminds me of your talks with David Goggins of course and a few other conversations of yours these subjects discussed are invaluable be it pushing to limits or just making progress the value is there for anyone to get active.',
#    'timestamp': '2026-01-16T14:20:09Z',
#    'authorId': 'UC0Qy2XDwR_QuFt8tIlcZrxg'},
#   'sentiment': '-1'},
#  {'comment': {'text': 'I would love to see a discussion between Sam Harris and you on God, conscience and the idea of self. Didn’t know where to post my comment! Love your channel and podcasts ❤',
#    'timestamp': '2026-01-16T10:02:01Z',
#    'authorId': 'UCleABqu1f-293mjmrADHRcA'},
#   'sentiment': '1'},
#  {'comment': {'text': "u folks too Smart \nfascinating re: memorable shtufffs!!\n\nsucks about theft, Ms. Suzuki!! \nDid you get New shirts?\nMy babcią  Ate liver with marjoram & apples    she was still depressed, yet had such Patiance and Dexterity \n   hallelujah.  \n  A friend had all his tye dye shirts stolen by BADNESS,   chalk it up to badness.\n    meanwhile there were thousand dollars juicers, Persian rugs , essentially More valuable items yet  thiese thieves weren't interested in lifting the Heavy load \n 008",
#    'timestamp': '2026-01-16T09:49:49Z',
#    'authorId': 'UCvX4MpoGSljGN-wlo3vA0uw'},
#   'sentiment': '1'},
#  {'comment': {'text': 'I don’t like to turn on my lights in my room so if I need something I just reach for it in the dark and my accuracy is 100% and I wonder if that’s from a level of spatial awareness that comes with being blind and staying in the same room my whole life',
#    'timestamp': '2026-01-16T07:46:37Z',
#    'authorId': 'UC2l7PW5y950ASHbUg388WaQ'},
#   'sentiment': '1'},
#  {'comment': {'text': 'My grandfather used to do yoga every single day without fail till he passed away.  He got covid at the age of 93 and he beat it. We all attribute it to his exercising and healthy eating habits.\nHe lived on till 96 and he had the most amazing memory. He would recount numerous stories from his younger days and he rarely forgot people and used to tell us stories that even we had forgotten.\n\nHe did donate his brain and eyes to the medical school in our city, so that they could research. He used to say it’s better if my body is used for science than turning into soil. \nPoint being: exercise helps!',
#    'timestamp': '2026-01-16T05:08:16Z',
#    'authorId': 'UCh9BP9gH1CnBTvY046dAKsA'},
#   'sentiment': '1'},
#  {'comment': {'text': "What do you think about Polyvagal theory? I'm interested.😗",
#    'timestamp': '2026-01-16T04:21:35Z',
#    'authorId': 'UCjDt_VOcAy0tf2eUs1t-8Nw'},
#   'sentiment': '0'},
#  {'comment': {'text': 'Tuning in to another great learning session, just wondering if being in nature for a few days without technology distractions will promote better memory and improve focus in the long term. Being a introvert, I truly enjoyed solitary and had been planning a trip to Fraser Hill for a while for the purpose. Closer to nature and skipping life distraction had improve my wellbeing in the past AND is hoping it will replicate itself again this time round. Just in case you dont know where is Fraser Hill, it is in Malaysia and I am a Malaysian. Thanks Dr Andrew for all the delightful podcasta that enrich my knowledge in life.',
#    'timestamp': '2026-01-16T03:41:04Z',
#    'authorId': 'UCOpOnXtHKjE8zh2hrm4Tk7A'},
#   'sentiment': '1'},
#  {'comment': {'text': 'Exercise meditation and sleep are the 3 tools for a bigger fluffier hippocampus',
#    'timestamp': '2026-01-16T03:03:27Z',
#    'authorId': 'UC9gL3lHeqXgYFthVFPHCYtg'},
#   'sentiment': '0'},
#  {'comment': {'text': "Hi Andrew - I'm a huge fan of the podcast. The information you share genuinely improves my mental and physical health. That being said, many of the protocols you describe for optimal health/performance (in many areas) go against what I am being taught by other resources about women's hormone health, specifically hypothalamic amenorrhea and restrictive eating disorder recovery. \n\nI was wondering if you would consider discussing these topics and how daily protocols around food, fasting, and exercise may differ. Specifically, I would love to know your take on the literature surrounding the adapted to flee famine hypothesis, the cognitive and physical side effects of under-eating (even moderate), and other related phenomena. I've heard mixed discourse about post-starvation hyperphagia, set point theory, etc, and I think many people today would appreciate a true scientific discussion here.",
#    'timestamp': '2026-01-16T02:41:59Z',
#    'authorId': 'UCBJZZCpk63Onb8nPZuwMu8Q'},
#   'sentiment': '1'},
#  {'comment': {'text': '❤',
#    'timestamp': '2026-01-16T01:30:54Z',
#    'authorId': 'UCtTNAMaeuZOuBNNKn1qosSA'},
#   'sentiment': '0'},
#  {'comment': {'text': 'Suzy Suzuki!!!',
#    'timestamp': '2026-01-16T01:19:18Z',
#    'authorId': 'UC4cnei-nHx7kkPkYAO8T8yQ'},
#   'sentiment': '0'},
#  {'comment': {'text': 'aderol',
#    'timestamp': '2026-01-16T00:38:57Z',
#    'authorId': 'UCmoK25l7cQJBBz1TqQ4Kj4A'},
#   'sentiment': '0'},
#  {'comment': {'text': 'The countless ways we humans are able to adapt, the depth of phenomenons and psychosomatic complexities is what geeks me going. Always something new to learn, and how that naturally makes us reflect and unlearn the patterns of which does not serve us in the long run is fascinating. Also how we normally think of pain and suffering as a bad thing but It’s there in nature as an actual well formed structure and signaling, that can translate in new possibilities for greater change if handled in a healthy manner and not procrastinated for a long period of time, is truly incredible.',
#    'timestamp': '2026-01-16T00:29:26Z',
#    'authorId': 'UCGZNbK8vf8Hb3q_iLw4tSDw'},
#   'sentiment': '1'},
#  {'comment': {'text': 'Gracias ❤',
#    'timestamp': '2026-01-15T23:59:45Z',
#    'authorId': 'UCyl7SczOFasnMyhFo41WP0A'},
#   'sentiment': '0'},
#  {'comment': {'text': 'I drank every time she said hippocampus…. Now I’m drunk \U0001fae8',
#    'timestamp': '2026-01-15T23:47:53Z',
#    'authorId': 'UCY5NmRhW-5yea-p9oPAxxDg'},
#   'sentiment': '0'},
#  {'comment': {'text': "I hate exercise. And I never seem to have time even though I try to make the time. Sometimes lifestyles just don't allow it.",
#    'timestamp': '2026-01-15T23:12:00Z',
#    'authorId': 'UCso0e9Qa1s8auwcqTJ5b6Ww'},
#   'sentiment': '-1'},
#  {'comment': {'text': 'I’ve observed that since your proclamation of being a Christian they’ve tamed down your online presence. I want to tell you that, this happens to Gods warriors and Please keep doing this because the only people that it will change anyways, are the people that actively search for it. Just like Jordan P',
#    'timestamp': '2026-01-15T22:38:54Z',
#    'authorId': 'UCeWaTvriCJXKLE6owAF28Sg'},
#   'sentiment': '0'},
#  {'comment': {'text': 'I like this format!',
#    'timestamp': '2026-01-15T22:15:12Z',
#    'authorId': 'UCsbdKlqxhy7SrjCNA_IgAMA'},
#   'sentiment': '0'},
#  {'comment': {'text': 'What about the ability to recall? How can one improve that? Things you know you know but cant seem to lay your hands on sometimes?',
#    'timestamp': '2026-01-15T22:13:25Z',
#    'authorId': 'UChWP5ysrkahjTQwx3SayqoA'},
#   'sentiment': '1'},
#  {'comment': {'text': 'Great, but how does exercise intensity play into maintaining cognitive function? I’m talking Tom Platz level',
#    'timestamp': '2026-01-15T21:47:53Z',
#    'authorId': 'UCKYX9X09aI3-6tZzP0P6qPg'},
#   'sentiment': '1'},
#  {'comment': {'text': '💛🧡💛🧡',
#    'timestamp': '2026-01-15T21:35:41Z',
#    'authorId': 'UCduczX1e6oZF4xXTBm3YVrg'},
#   'sentiment': '0'},
#  {'comment': {'text': 'How is your wifes mental health?',
#    'timestamp': '2026-01-15T20:16:10Z',
#    'authorId': 'UC2ADecI0qrUY9OdFXR1lQag'},
#   'sentiment': '-1'},
#  {'comment': {'text': 'You cheated on your wife.',
#    'timestamp': '2026-01-15T20:15:58Z',
#    'authorId': 'UC2ADecI0qrUY9OdFXR1lQag'},
#   'sentiment': '0'},
#  {'comment': {'text': 'I’ve been waiting for this 😏',
#    'timestamp': '2026-01-15T20:01:45Z',
#    'authorId': 'UCJes9Hx2SPEIF8s3OjiTSQw'},
#   'sentiment': '0'},
#  {'comment': {'text': 'Evolution yuck',
#    'timestamp': '2026-01-15T19:28:13Z',
#    'authorId': 'UCb9R5bFMgev-FgRjefHwNJQ'},
#   'sentiment': '0'},
#  {'comment': {'text': 'I want a bigger fatter fluffier hippocampus.',
#    'timestamp': '2026-01-15T19:24:17Z',
#    'authorId': 'UC1y5fQ4Mt7dOtT1NEwQIriQ'},
#   'sentiment': '0'},
#  {'comment': {'text': 'Great guest! Lots of charisma and knowledge. Thanks for the interview.',
#    'timestamp': '2026-01-15T19:24:12Z',
#    'authorId': 'UCY1SrhzFirdrVqgK8MrRTQQ'},
#   'sentiment': '1'},
#  {'comment': {'text': 'Sorry, don’t have the attention span to watch this video',
#    'timestamp': '2026-01-15T19:17:40Z',
#    'authorId': 'UCV9t4z9VK0NaGJimi3Ldg3Q'},
#   'sentiment': '-1'},
#  {'comment': {'text': 'Huba is the dawg. Thanks bruv 🔥',
#    'timestamp': '2026-01-15T19:09:41Z',
#    'authorId': 'UCPACWy9LAeyxgQSzuVNWuZA'},
#   'sentiment': '1'},
#  {'comment': {'text': 'When I went to CognitiveFX in Provo Utah for a TBI, they had me do many of the exercises mentioned here and in 5 days I went from being in a state of a two year old to thinking and walking like an adult. God has so richly blessed these people with helping others with these non-invasive methods. Thank you and God bless you all.',
#    'timestamp': '2026-01-15T19:00:17Z',
#    'authorId': 'UCe0GHo0yaZX97pdbvkdVXBQ'},
#   'sentiment': '1'},
#  {'comment': {'text': '10:30 \nI’m in the same boat \nMy mother isn’t doing well all of a sudden, I’m desperately grasping for information on how to help her, this podcast is a great resource and look forward to hearing the rest of this one especially now…❤',
#    'timestamp': '2026-01-15T18:58:45Z',
#    'authorId': 'UCmyuOL90a4-bMNwGYusW0Ug'},
#   'sentiment': '1'},
#  {'comment': {'text': 'So, exercise.\nThanks for the advice.',
#    'timestamp': '2026-01-15T18:40:14Z',
#    'authorId': 'UCAgi_DQcqk0_ikJR5Gz3M2Q'},
#   'sentiment': '1'},
#  {'comment': {'text': 'The idea that being physically fit correlates with improved cognitive function makes total sense. As good materialists we acknowledge the brain is just a part of the body etc. But…it just don’t seem to for me. In my daily life I have to use my brain a lot with self motivation and a little inspiration. I’m always at my most productive when I’m in a sedentary phase of life. I’ll keep trying and be sure not to ‘overtrain’ etc, but yeh…',
#    'timestamp': '2026-01-15T18:15:38Z',
#    'authorId': 'UC_G5QCx3R8jf8mSC8LAzr8w'},
#   'sentiment': '1'},
#  {'comment': {'text': 'Please keep your videos short - people with adhd can’t keep up with 2 hours + videos 🙏\U0001fa75',
#    'timestamp': '2026-01-15T18:03:31Z',
#    'authorId': 'UCP6DF-kyrl_8eoVEjoxj23Q'},
#   'sentiment': '0'},
#  {'comment': {'text': 'Tool for memory: JUST STOP FORGETTING',
#    'timestamp': '2026-01-15T17:31:49Z',
#    'authorId': 'UCcf-g1bvp46WRFfn5hNPI1Q'},
#   'sentiment': '0'},
#  {'comment': {'text': 'I can’t tell you how happy I am about this episode. Extremely happy that you and Wendy are getting together after a few years. I still watch the very first time you bought her as a guest to this day on repeat. You guys are my neuroplastic parents.❤',
#    'timestamp': '2026-01-15T17:17:33Z',
#    'authorId': 'UCVdRkIjw0QOpgomxPSIufvw'},
#   'sentiment': '1'},
#  {'comment': {'text': "She's so inspiring! Great episode!",
#    'timestamp': '2026-01-15T16:54:22Z',
#    'authorId': 'UCtwaDWIodNMJmdWSUdbuyNA'},
#   'sentiment': '1'},
#  {'comment': {'text': "I'm big fan of your podcast from India since 2019\nI would like request you to add Hindi language",
#    'timestamp': '2026-01-15T16:35:46Z',
#    'authorId': 'UCQDY7NsB0UFgS-hQt2_1O1w'},
#   'sentiment': '0'},
#  {'comment': {'text': 'In 1921  Dr. Russell Wilder at the Mayo Clinic coined the term ketogenic diet for epilepsy.  Hopefully they tried the ketogenic diet on the guy HM before removing his hippocampus.',
#    'timestamp': '2026-01-15T16:25:27Z',
#    'authorId': 'UCIogvw7FEc5BmS1Pw3eMTrg'},
#   'sentiment': '0'},
#  {'comment': {'text': 'Thanks for keeping this one short, my attention span was struggling! /s',
#    'timestamp': '2026-01-15T16:22:16Z',
#    'authorId': 'UC3vEvFVSOmROqaCOVHBd6aQ'},
#   'sentiment': '1'},
#  {'comment': {'text': '15 mins in all she does is talk about herself. L',
#    'timestamp': '2026-01-15T16:18:50Z',
#    'authorId': 'UCz9xuwIGBQ-wESwZpV5fFEQ'},
#   'sentiment': '0'},
#  {'comment': {'text': 'LOVE HER!!!! Thank you teacher',
#    'timestamp': '2026-01-15T16:18:24Z',
#    'authorId': 'UCLwBQoJuwJi85m0NX22hmZA'},
#   'sentiment': '1'},
#  {'comment': {'text': "Does Wendy have a new book coming out, something new to sell? Maybe some online courses? Come on... sell something... it's what podcasts are now, promo tour",
#    'timestamp': '2026-01-15T16:12:58Z',
#    'authorId': 'UCenQITNB1IIQRrJcY-V8XGQ'},
#   'sentiment': '1'},
#  {'comment': {'text': 'How many women were shamed and tortured for this video? Is the new article on SEDUCTIONS OF ANDREW coming out soon??',
#    'timestamp': '2026-01-15T16:11:58Z',
#    'authorId': 'UCenQITNB1IIQRrJcY-V8XGQ'},
#   'sentiment': '1'},
#  {'comment': {'text': 'Hi Andrew! Could you make an episode with Jonny Kim, please?',
#    'timestamp': '2026-01-15T15:59:10Z',
#    'authorId': 'UCMQ2UHt-BvXSKtcqjASrV6g'},
#   'sentiment': '0'},
#  {'comment': {'text': "I'm preparing for exams this video is perfect for this time 😂❤",
#    'timestamp': '2026-01-15T15:56:30Z',
#    'authorId': 'UCIHTUwpnBV19ZTj0K_VveFQ'},
#   'sentiment': '1'},
#  {'comment': {'text': "I'm loving the background.😮😮😮😊",
#    'timestamp': '2026-01-15T15:55:40Z',
#    'authorId': 'UClsFOXHCjQfpuEndC5F5azQ'},
#   'sentiment': '0'},
#  {'comment': {'text': "What's wrong with her hands dude 😎.",
#    'timestamp': '2026-01-15T15:54:30Z',
#    'authorId': 'UClsFOXHCjQfpuEndC5F5azQ'},
#   'sentiment': '-1'},
#  {'comment': {'text': "21:00 +++++ I'm not familiar with all that terminology . Although in my experience writing ✍️ is very therapeutic for depression and anxiety. 23:00+++++30:00+++++34:00+++++36:00+++++❤️❤️❤️❤️❤️",
#    'timestamp': '2026-01-15T15:45:54Z',
#    'authorId': 'UCxmsE9RK77_aC0fDoZTqwiw'},
#   'sentiment': '0'},
#  {'comment': {'text': 'HUB- Hub',
#    'timestamp': '2026-01-15T15:42:03Z',
#    'authorId': 'UCibXe74D_kRBHIoEh2wLcyw'},
#   'sentiment': '0'},
#  {'comment': {'text': 'Using your mind I would imagine is a tremendous help. Writing ✍️, mind games, word games, creative work, gardening, working with your hands and positive actions.',
#    'timestamp': '2026-01-15T15:34:57Z',
#    'authorId': 'UCxmsE9RK77_aC0fDoZTqwiw'},
#   'sentiment': '1'},
#  {'comment': {'text': 'I am resuming my gym session tomorrow',
#    'timestamp': '2026-01-15T15:34:48Z',
#    'authorId': 'UCTk14B97FRoqVYsflrYLErQ'},
#   'sentiment': '0'},
#  {'comment': {'text': "On the issue of the benefit of employing positive affirmations with exercise, check out the book What to Say When You Talk to Yourself by Shad Helmstetter. Chapter 4 explains how the subconscious only relates to images of outcomes and guides our conscious behavior and why creating positive images (ie Drive safely vs Don't have an accident) guides conscious behaviors, to better outcomes.",
#    'timestamp': '2026-01-15T14:58:56Z',
#    'authorId': 'UCc_Yzm0yUb-EvkNR7BSYBdw'},
#   'sentiment': '1'},
#  {'comment': {'text': 'Mindblowing!',
#    'timestamp': '2026-01-15T14:54:09Z',
#    'authorId': 'UC9-vxVOmxulwgtoma2SDU1w'},
#   'sentiment': '0'},
#  {'comment': {'text': 'Does taking preworkout help or ruin this experience',
#    'timestamp': '2026-01-15T14:52:10Z',
#    'authorId': 'UCf4hSBnThbxfK32bIUedKTw'},
#   'sentiment': '0'},
#  {'comment': {'text': 'I love this lady',
#    'timestamp': '2026-01-15T14:51:00Z',
#    'authorId': 'UCE4lYLYzAlBmjPvJFkHxnXQ'},
#   'sentiment': '1'},
#  {'comment': {'text': '** please consider Dr John Delony  on the show to talk on relationships! He’s been on Jordan Peterson and has a great podcast of his own',
#    'timestamp': '2026-01-15T14:45:27Z',
#    'authorId': 'UC-5tcCqnM2X5NfcuOuUTsAA'},
#   'sentiment': '1'},
#  {'comment': {'text': 'These supplements also help deliver Stroger Blood flow to the Brain and Higher neural capacity.\nL‑Arginine ---Expands pathways, increases flow, removes constriction.\r\nL‑Tyrosine —Crafts the neurotransmitters that carry intent into action.\r\nDMG —Quietly fuels methylation, oxygenation, and resilience.\r\nNAD —The spark of cellular vitality, guarding against decay.\r\nCDP‑Choline —Builds and repairs the structures of thought.\r\nPantothenic Acid —Converts raw material into usable energy and motion.\r\nTogether they form a system of flow → focus → energy → longevity → cognition → structure → metabolism.\nFormulated properly with the previous supplements helps deliver the nutrients the brain needs to heal itself and reduce cellular damage.\nNeuroplasticity and Brain cell regeneration.\r\nHelps with blood flow and oxygen travel to the brain while increasing focus and memory. Also reduces cell damage and anti-bacterial/microbial. Helps with digestion and absorption into the blood stream. Taken orally as a supplement. Improves Liver function and gut health as well.\r\nLions Mane, Shiitake, Oyster Mushroom, Mitake, Porcini, Ginkobiloba, Griffonia, Citicoline,Siberian Genseng, Ashwiganda, Cogizin, Peoria Fungus, Schisandra, Passion Flower, Shilajit, Juniper Berries, Goji Berries,Cloves, Lemon Balm, Irish Sea Moss, Pink Peppercorns.',
#    'timestamp': '2026-01-15T14:32:41Z',
#    'authorId': 'UCo9uR_AEeUQXuXHOrP0m7RA'},
#   'sentiment': '-1'},
#  {'comment': {'text': 'NOVELTY',
#    'timestamp': '2026-01-15T14:15:18Z',
#    'authorId': 'UCxxuwQJ2PAZNr8r0WoGsGhw'},
#   'sentiment': '0'},
#  {'comment': {'text': 'Botem áudio em português br',
#    'timestamp': '2026-01-15T14:14:34Z',
#    'authorId': 'UCDoxnrkb5mWwUNt8FkP3vlQ'},
#   'sentiment': '0'},
#  {'comment': {'text': 'Bookmark 12:24',
#    'timestamp': '2026-01-15T14:13:01Z',
#    'authorId': 'UCXqWFGUSoAL89zQz_Vfdecw'},
#   'sentiment': '0'},
#  {'comment': {'text': 'Excellent information and discussion including practical reminder of ways we can increase beneficial ways to improve our lives.',
#    'timestamp': '2026-01-15T14:10:41Z',
#    'authorId': 'UCzDQCl5_XjE_pTT-6YbV7HQ'},
#   'sentiment': '1'},
#  {'comment': {'text': 'BH4 is an essential cofactor for many enzymes including nitric-oxide synthase and phenylalanine hydroxylase where it can act as either an electron donor or in oxygen insertion. More Oxygen to the brain means higher brain functioning. The brain also functions by electrical and chemical responses.',
#    'timestamp': '2026-01-15T13:42:02Z',
#    'authorId': 'UCo9uR_AEeUQXuXHOrP0m7RA'},
#   'sentiment': '1'},
#  {'comment': {'text': 'Neuroplasticity and Brain cell regeneration.\r\nHelps with blood flow and oxygen travel to the brain while increasing focus and memory. Also reduces cell damage and anti-bacterial/microbial. Helps with digestion and absorption into the blood stream. Taken orally as a supplement. Improves Liver function and gut health as well.\r\n\r\nLions Mane, Shiitake, Oyster Mushroom, Mitake, Porcini, Ginkobiloba, Griffonia, Citicoline,Siberian Genseng, Ashwiganda, Cogizin, Peoria Fungus, Schisandra, Passion Flower, Shilajit, Juniper Berries, Goji Berries,Cloves, Lemon Balm, Irish Sea Moss, Pink Peppercorns.',
#    'timestamp': '2026-01-15T13:40:35Z',
#    'authorId': 'UCo9uR_AEeUQXuXHOrP0m7RA'},
#   'sentiment': '0'},
#  {'comment': {'text': 'This episode made me rethink how I approach both my workouts and my workdays. There is something powerful about syncing physical effort with mental clarity.',
#    'timestamp': '2026-01-15T13:39:43Z',
#    'authorId': 'UCUdLE8REJor87hPwOIEM4MQ'},
#   'sentiment': '1'},
#  {'comment': {'text': 'No colonel sanders your wrong, mamas right',
#    'timestamp': '2026-01-15T13:28:37Z',
#    'authorId': 'UC9QrL7tzI7lNE5vZyrKgUWQ'},
#   'sentiment': '-1'},
#  {'comment': {'text': 'Hello friends  I am from India,, excellent podcast 🎉🎉🎉',
#    'timestamp': '2026-01-15T13:19:14Z',
#    'authorId': 'UC9Q37LsIrP8cgoj2PJ7o01w'},
#   'sentiment': '1'},
#  {'comment': {'text': 'Great info, does hit / interval training have similar effects?🇬🇧👍',
#    'timestamp': '2026-01-15T13:18:46Z',
#    'authorId': 'UCADFMwfha-Z2NJ1CBStPzHQ'},
#   'sentiment': '1'},
#  {'comment': {'text': 'much needed video thanks 🙌🏻',
#    'timestamp': '2026-01-15T13:15:11Z',
#    'authorId': 'UC27LgpJDd-5Gd2sIsVYtezQ'},
#   'sentiment': '1'},
#  {'comment': {'text': '❤',
#    'timestamp': '2026-01-15T13:13:22Z',
#    'authorId': 'UCvARYGArZbcmPCEFGBfqGhQ'},
#   'sentiment': '0'},
#  {'comment': {'text': 'A new Andrew Huberman? A wonderful way to begin my hump day 🖤',
#    'timestamp': '2026-01-15T13:13:02Z',
#    'authorId': 'UCxWnqBh-OGKxkCllv5m3CZw'},
#   'sentiment': '1'},
#  {'comment': {'text': 'When will take interview from muniba mazari',
#    'timestamp': '2026-01-15T13:12:44Z',
#    'authorId': 'UCYee2CvfsE-i6O_ZXZ_HIpw'},
#   'sentiment': '0'},
#  {'comment': {'text': 'I profoundly appreciate how accessible this information is',
#    'timestamp': '2026-01-15T13:12:26Z',
#    'authorId': 'UCVEYnOQEl-ZiTIkbLeg5u-w'},
#   'sentiment': '0'},
#  {'comment': {'text': 'Dr. Wendy Suzuki discusses how exercise, meditation, and sleep enhance brain function. Exercise releases BDNF, promoting hippocampus growth and improving memory. Just 10 minutes of walking boosts mood, while 2-3 weekly cardio sessions improve cognition. Brief meditation and proper sleep further optimize attention and cognitive performance.',
#    'timestamp': '2026-01-15T13:12:02Z',
#    'authorId': 'UCR8Za9xyJHs6jd-hDw1hD2w'},
#   'sentiment': '0'},
#  {'comment': {'text': 'Dr. Wendy Suzuki discusses how exercise, meditation, and sleep enhance brain function. Exercise releases BDNF, promoting hippocampus growth and improving memory. Just 10 minutes of walking boosts mood, while 2-3 weekly cardio sessions improve cognition. Brief meditation and proper sleep further optimize attention and cognitive performance.',
#    'timestamp': '2026-01-15T13:12:02Z',
#    'authorId': 'UCR8Za9xyJHs6jd-hDw1hD2w'},
#   'sentiment': '0'},
#  {'comment': {'text': 'Love the video!!!',
#    'timestamp': '2026-01-15T13:09:45Z',
#    'authorId': 'UC4NPo8Ufz5d_QJxsfCLhGxQ'},
#   'sentiment': '1'},
#  {'comment': {'text': 'Transformer architecture needs this',
#    'timestamp': '2026-01-15T13:08:27Z',
#    'authorId': 'UCxa8kSHJqwL2epukHnnQjXA'},
#   'sentiment': '0'},
#  {'comment': {'text': 'So, novelty-repetition-association-emotional resonance, did I remember correctly? Thanks for another interesting episode!',
#    'timestamp': '2026-01-15T13:06:45Z',
#    'authorId': 'UC50ryCZ0Q65DwJM6ejJ_6Fg'},
#   'sentiment': '1'},
#  {'comment': {'text': "3rd 😂. Wish you all great year ahead! Let's learn and improve our lives.",
#    'timestamp': '2026-01-15T13:04:51Z',
#    'authorId': 'UCxolHyWxcpntUdtzc6rdBlQ'},
#   'sentiment': '1'},
#  {'comment': {'text': '2nd',
#    'timestamp': '2026-01-15T13:02:15Z',
#    'authorId': 'UCCkCQAdTkphLCoHvAvqid9w'},
#   'sentiment': '0'},
#  {'comment': {'text': 'i rushed asap',
#    'timestamp': '2026-01-15T13:02:14Z',
#    'authorId': 'UCO_7ecnAz8U5AiR3AjPITsQ'},
#   'sentiment': '0'},
#  {'comment': {'text': 'Best Guy in this Whole World 🌎',
#    'timestamp': '2026-01-15T13:01:49Z',
#    'authorId': 'UCIip6BFaZJAfwlIBVRrjojQ'},
#   'sentiment': '1'}]

# %%
import pandas as pd
transformed_comments = tfidf_vectorizer.transform([comment])
input_schema = model.metadata.get_input_schema()
expected_columns = input_schema.input_names()

# Convert sparse matrix to DataFrame with vectorizer features
feature_names = tfidf_vectorizer.get_feature_names_out()
df = pd.DataFrame(transformed_comments.toarray(), columns=feature_names)
print(df.shape)
 # Add missing expected columns with zeros
for col in expected_columns:
    if col not in df.columns:
        df[col] = 0.0
# Reorder columns exactly as model expects
df = df[expected_columns]
predictions = model.predict(df).tolist()
predictions = [str(pred) for pred in predictions]
predictions
# Out:
# (1, 10000)
# ['1']

# %%
print(transformed_comments)
# Out:
# <Compressed Sparse Row sparse matrix of dtype 'float64'
# 	with 8 stored elements and shape (1, 10000)>
#   Coords	Values
#   (0, 575)	0.38752454417944343
#   (0, 2715)	0.33319391100353063
#   (0, 2857)	0.3886141199705799
#   (0, 5231)	0.25132656002531284
#   (0, 5485)	0.4152417565499547
#   (0, 6732)	0.41003993171670844
#   (0, 6929)	0.35366413515959577
#   (0, 8319)	0.2428657835737687
